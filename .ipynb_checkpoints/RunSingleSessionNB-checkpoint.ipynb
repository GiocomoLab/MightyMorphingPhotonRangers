# %%
import os
os.sys.path.append("C:\\Users\mplitt\MightyMorphingPhotonRangers")
import utilities as u
import preprocessing as pp
import single_session_plots as ssp
import numpy as np
import SimilarityMatrixAnalysis as sm
import PlaceCellAnalysis as pc
import scipy as sp
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
df = pp.load_session_db(twop_dir = "G:\\My Drive\\2P_Data\\Syt3KO")
# df = pp.load_session_db()
df = df[df['RewardCount']>20]
df = df[df['Imaging']==1]
df = df.sort_values(['MouseName','DateTime','SessionNumber'])
# Out:
# G:\My Drive\VR_Data\TwoTower\behavior.sqlite
# G:\My Drive\VR_Data\TwoTower\4222174.0\30_05_2019\RuningTraining_1.sqlite
# file doesn't exist, errors to come!!!
# G:\My Drive\VR_Data\TwoTower\4222168.1\09_08_2019\RuningTraining_1.sqlite
# file doesn't exist, errors to come!!!
# G:\My Drive\VR_Data\TwoTower\4222169.2\26_08_2019\TwoTower_Timeout_0.sqlite
# file doesn't exist, errors to come!!!

# %%
ops = {'behavior':True,
    'PCA':False,
    'place cells':True,
    'trial simmats':True,
    'trial NMF':False,
    'realtime lar':True,
    'savefigs':True}

# %%
mouse = '4343705.3'
df_mouse = df[df['MouseName'].str.match(mouse)]
df_mouse
# Out:
#       MouseName  DateFolder  SessionNumber               Track  RewardCount  \
# 3074  4343705.3  13_01_2020              2  TwoTower_noTimeout           61
# 3103  4343705.3  15_01_2020              4  TwoTower_noTimeout           52
#
#       Imaging ImagingRegion   DateTime  \
# 3074        1           CA1 2020-01-13
# 3103        1           CA1 2020-01-15
#
#                                               data file scanfile  \
# 3074  G:\My Drive\VR_Data\TwoTower\4343705.3\13_01_2...     None
# 3103  G:\My Drive\VR_Data\TwoTower\4343705.3\15_01_2...     None
#
#                                                 scanmat  \
# 3074  G:\My Drive\2P_Data\Syt3KO\4343705.3\13_01_202...
# 3103  G:\My Drive\2P_Data\Syt3KO\4343705.3\15_01_202...
#
#                                               s2pfolder
# 3074  G:\My Drive\2P_Data\Syt3KO\4343705.3\13_01_202...
# 3103  G:\My Drive\2P_Data\Syt3KO\4343705.3\15_01_202...

# %%
sess=df_mouse.iloc[-1]
ssp.single_session_figs(sess,ops=ops,twotower=False)
# Out:
# num aberrant ttls 0.0
# 30663 (30663,) (30663, 21) 85117
# (85117,) (85117, 21)
# 8.656013137948458 1983.311015664477
# 0.0 1983.1915108640728
# C:\Users\mplitt\Anaconda3\lib\site-packages\pandas\core\frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# frame diff 0
# neg inds: 639916
# start bootstrap
# end bootstrap
# C:\Users\mplitt\MightyMorphingPhotonRangers\utilities.py:119: RuntimeWarning: Mean of empty slice
#   frmap[i] = np.nanmean(C[(position>edge1) & (position<=edge2),:],axis=0)
# start bootstrap
# end bootstrap
# morph 0 place cells = 66 out of 2484 , 0.026570
# morph 1 place cells = 138 out of 2484, 0.055556
# (2484, 45) (45, 2484)
# negative similarity inds: 0
# 3.3697651919063363
# 2.3163310598923923
# 1.4265380194876458
# -0.043549502399561735
# 0.23385569937390016
# -0.3178185872523122
# 0.33072311098053536
# -0.06580947782618174
# 5.130416639957809
# 5.331981954882604
# 6.556255564269669
# 5.080366861760712
# 6.400366779761078
# 6.31768193446664
# 5.446969498538942
# 6.049809788235374
