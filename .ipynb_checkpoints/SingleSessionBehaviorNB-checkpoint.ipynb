# %%
import os
os.sys.path.append("C:\\Users\mplitt\MightyMorphingPhotonRangers")
import numpy as np
import matplotlib.pyplot as plt

import utilities as u
import preprocessing as pp
import behavior as b
import SimilarityMatrixAnalysis as sm
import scipy as sp
import PlaceCellAnalysis as pc
from SplineEncodingModel.LinearRegressionSpline import EncodingModel, NBDecodingModel
from SplineEncodingModel import PopDecodingCV as pdcv
import matplotlib.gridspec as gridspec
import pickle

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
df = pp.load_session_db()


df = df[df['RewardCount']>20]
df = df[df['Imaging']==1]
df = df.sort_values(['MouseName','DateTime','SessionNumber'])
tracks = 'TwoTower_noTimeout|TwoTower_Timeout|Reversal_noTimeout|Reversal|TwoTower_foraging|FreqMorph_Timeout'
df = df[df['Track'].str.contains(tracks,regex=True)]
# Out:
# G:\My Drive\VR_Data\TwoTower\behavior.sqlite
# G:\My Drive\VR_Data\TwoTower\4222174.0\30_05_2019\RuningTraining_1.sqlite
# file doesn't exist, errors to come!!!
# G:\My Drive\VR_Data\TwoTower\4222168.1\09_08_2019\RuningTraining_1.sqlite
# file doesn't exist, errors to come!!!
# G:\My Drive\VR_Data\TwoTower\4222169.2\26_08_2019\TwoTower_Timeout_0.sqlite
# file doesn't exist, errors to come!!!

# %%
mouse = '4139278.2'
df_mouse = df[df['MouseName'].str.match(mouse)]
# df_mouse = df_mouse[df_mouse['Track'].str.match('TwoTower_noTimeout') | df_mouse['Track'].str.match('TwoTower_Timeout')]
df_mouse
# Out:
#       MouseName  DateFolder  SessionNumber               Track  RewardCount  \
# 2040  4139278.2  08_06_2019              1   FreqMorph_Timeout           35
# 2070  4139278.2  11_06_2019              2   FreqMorph_Timeout           43
# 2090  4139278.2  13_06_2019              1   FreqMorph_Timeout           79
# 2105  4139278.2  14_06_2019              1   FreqMorph_Timeout           50
# 2146  4139278.2  18_06_2019              8  TwoTower_noTimeout           58
# 2170  4139278.2  20_06_2019              3  TwoTower_noTimeout           85
# 2187  4139278.2  23_06_2019              2  TwoTower_noTimeout          100
# 2201  4139278.2  24_06_2019              2  TwoTower_noTimeout           50
# 2208  4139278.2  25_06_2019              2  TwoTower_noTimeout          100
#
#       Imaging ImagingRegion   DateTime  \
# 2040        1           CA1 2019-06-08
# 2070        1           CA1 2019-06-11
# 2090        1               2019-06-13
# 2105        1           CA1 2019-06-14
# 2146        1               2019-06-18
# 2170        1           CA1 2019-06-20
# 2187        1           CA1 2019-06-23
# 2201        1           CA1 2019-06-24
# 2208        1           CA1 2019-06-25
#
#                                               data file scanfile  \
# 2040  G:\My Drive\VR_Data\TwoTower\4139278.2\08_06_2...     None
# 2070  G:\My Drive\VR_Data\TwoTower\4139278.2\11_06_2...     None
# 2090  G:\My Drive\VR_Data\TwoTower\4139278.2\13_06_2...     None
# 2105  G:\My Drive\VR_Data\TwoTower\4139278.2\14_06_2...     None
# 2146  G:\My Drive\VR_Data\TwoTower\4139278.2\18_06_2...     None
# 2170  G:\My Drive\VR_Data\TwoTower\4139278.2\20_06_2...     None
# 2187  G:\My Drive\VR_Data\TwoTower\4139278.2\23_06_2...     None
# 2201  G:\My Drive\VR_Data\TwoTower\4139278.2\24_06_2...     None
# 2208  G:\My Drive\VR_Data\TwoTower\4139278.2\25_06_2...     None
#
#                                                 scanmat  \
# 2040  G:\My Drive\2P_Data\TwoTower\4139278.2\08_06_2...
# 2070  G:\My Drive\2P_Data\TwoTower\4139278.2\11_06_2...
# 2090  G:\My Drive\2P_Data\TwoTower\4139278.2\13_06_2...
# 2105  G:\My Drive\2P_Data\TwoTower\4139278.2\14_06_2...
# 2146  G:\My Drive\2P_Data\TwoTower\4139278.2\18_06_2...
# 2170  G:\My Drive\2P_Data\TwoTower\4139278.2\20_06_2...
# 2187  G:\My Drive\2P_Data\TwoTower\4139278.2\23_06_2...
# 2201  G:\My Drive\2P_Data\TwoTower\4139278.2\24_06_2...
# 2208  G:\My Drive\2P_Data\TwoTower\4139278.2\25_06_2...
#
#                                               s2pfolder
# 2040  G:\My Drive\2P_Data\TwoTower\4139278.2\08_06_2...
# 2070  G:\My Drive\2P_Data\TwoTower\4139278.2\11_06_2...
# 2090  G:\My Drive\2P_Data\TwoTower\4139278.2\13_06_2...
# 2105  G:\My Drive\2P_Data\TwoTower\4139278.2\14_06_2...
# 2146  G:\My Drive\2P_Data\TwoTower\4139278.2\18_06_2...
# 2170  G:\My Drive\2P_Data\TwoTower\4139278.2\20_06_2...
# 2187  G:\My Drive\2P_Data\TwoTower\4139278.2\23_06_2...
# 2201  G:\My Drive\2P_Data\TwoTower\4139278.2\24_06_2...
# 2208  G:\My Drive\2P_Data\TwoTower\4139278.2\25_06_2...

# %%
sess = df_mouse.iloc[-1]

# %%
VRDat = pp.behavior_dataframe(sess['data file'])
trial_info, tstart_inds, teleport_inds = u.by_trial_info(VRDat)
lick_trial_mat,occ,edges,centers= u.make_pos_bin_trial_matrices(VRDat['lick']._values,
                                                            VRDat['pos']._values,
                                                            VRDat['tstart']._values,
                                                            VRDat['teleport']._values,
                                                            bin_size=10)
lick_trial_mat = lick_trial_mat[:,:]
print(lick_trial_mat.shape,trial_info['morphs'].shape)
lick_morph_dict = u.trial_type_dict(lick_trial_mat,trial_info['morphs'])
speed_trial_mat = u.make_pos_bin_trial_matrices(VRDat['speed']._values,
                                                        VRDat['pos']._values,
                                                        VRDat['tstart']._values,
                                                        VRDat['teleport']._values,
                                                        mat_only=True,bin_size=10)

effMorph = (trial_info['morphs']+trial_info['wallJitter']+trial_info['bckgndJitter']+.25)/1.5
reward_pos = trial_info['reward_pos']
reward_pos[np.isnan(reward_pos)]= 480.
f_lick, axarr_lick = b.behavior_raster_foraging(lick_trial_mat/np.nanmax(lick_trial_mat.ravel()),
                                                centers,effMorph,reward_pos/480.,smooth=False)
f_lick, axarr_lick = b.behavior_raster_task(lick_trial_mat/np.nanmax(lick_trial_mat.ravel()),
                                                centers,effMorph,reward_pos/480.,smooth=False)
f_speed,axarr_speed = b.behavior_raster_foraging(speed_trial_mat/np.nanmax(speed_trial_mat.ravel()),
                                                  centers,effMorph,reward_pos/480.,smooth=False)

f_lick, (ax_lick, meanlr_ax, lickrat_ax) = b.lick_plot_task(lick_morph_dict,edges,smooth=False)


f_sl, ax_spl = b.ant_speed_v_lick(lick_trial_mat,speed_trial_mat,centers,effMorph)
# Out:
# (100, 45) (100,)
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
