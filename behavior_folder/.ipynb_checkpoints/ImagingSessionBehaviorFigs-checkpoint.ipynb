# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import scipy as sp
from scipy.ndimage.filters import gaussian_filter1d
import sqlite3 as sql
import os
import pandas as pd
from datetime import datetime
from glob import glob
os.sys.path.append('../')
from utilities import *
from astropy.convolution import convolve, Gaussian1DKernel

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# C:\Users\mplitt\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# find sessions from single mouse on TwoTower_noTimeout with datestring earlier than or equal to first timeout day
# num rewards greater than 
df = load_session_db()
ca1mice = ['4139190.1','4139190.3', '4054011.1','4139202.2']
dgmice = ['4054010.4','4054010.5']

df = df[df['RewardCount']>10]
df = df[df['Imaging']==1]
df = df.sort_values(['MouseName','DateTime'])
df
# Out:
#      MouseName  DateFolder  SessionNumber                          Track  \
# 145  4054010.4  15_06_2018              2             TwoTower_noTimeout
# 361  4054010.5  15_06_2018              1             TwoTower_noTimeout
# 363  4054010.5  15_06_2018              2               TwoTower_Timeout
# 347  4054010.5  17_06_2018              2               TwoTower_Timeout
# 365  4054010.5  19_06_2018              2               TwoTower_Timeout
# 304  4054011.1  17_06_2018              2             TwoTower_noTimeout
# 311  4054011.1  19_06_2018              2               TwoTower_Timeout
# 306  4054011.1  21_06_2018              2               TwoTower_Timeout
# 212  4139190.1  15_06_2018              3             TwoTower_noTimeout
# 213  4139190.1  15_06_2018              1             TwoTower_noTimeout
# 150  4139190.1  16_06_2018              2               TwoTower_Timeout
# 151  4139190.1  16_06_2018              2             TwoTower_noTimeout
# 210  4139190.1  19_06_2018              2               TwoTower_Timeout
# 175  4139190.1  21_06_2018              3               TwoTower_Timeout
# 177  4139190.1  21_06_2018              2               TwoTower_Timeout
# 169  4139190.1  24_06_2018              2               TwoTower_Timeout
# 173  4139190.1  25_06_2018              2               TwoTower_Timeout
# 205  4139190.1  27_06_2018              2               TwoTower_Timeout
# 160  4139190.1  28_06_2018              8               TwoTower_Timeout
# 164  4139190.1  28_06_2018              2               TwoTower_Timeout
# 165  4139190.1  28_06_2018              9               TwoTower_Timeout
# 4    4139190.1  11_07_2018             17               TwoTower_Timeout
# 5    4139190.1  11_07_2018              1  TwoTower_BlackWhite_noTimeout
# 224  4139190.1  11_07_2018              1  TwoTower_BlackWhite_noTimeout
# 225  4139190.1  11_07_2018             17               TwoTower_Timeout
# 23   4139190.1  13_07_2018              1                       FlashLED
# 24   4139190.1  13_07_2018              1  TwoTower_BlackWhite_noTimeout
# 157  4139190.1  13_07_2018              1  TwoTower_BlackWhite_noTimeout
# 158  4139190.1  13_07_2018              1                       FlashLED
# 233  4139190.3  15_06_2018              3             TwoTower_noTimeout
# 234  4139190.3  15_06_2018              1             TwoTower_noTimeout
# 292  4139190.3  17_06_2018              2             TwoTower_noTimeout
# 245  4139190.3  19_06_2018              2               TwoTower_Timeout
# 278  4139190.3  21_06_2018              2               TwoTower_Timeout
# 281  4139190.3  25_06_2018              2               TwoTower_Timeout
# 273  4139190.3  28_06_2018              2               TwoTower_Timeout
# 20   4139190.3  12_07_2018              1               TwoTower_Timeout
# 21   4139190.3  12_07_2018              1  TwoTower_BlackWhite_noTimeout
# 22   4139190.3  12_07_2018              2               TwoTower_Timeout
# 294  4139190.3  12_07_2018              1               TwoTower_Timeout
G:\My Drive\2P_Data\TwoTower\4139190.3\12_07_2...
# 21   G:\My Drive\2P_Data\TwoTower\4139190.3\12_07_2...
# 22   G:\My Drive\2P_Data\TwoTower\4139190.3\12_07_2...
# 294  G:\My Drive\2P_Data\TwoTower\4139190.3\12_07_2...
# 295  G:\My Drive\2P_Data\TwoTower\4139190.3\12_07_2...
# 296  G:\My Drive\2P_Data\TwoTower\4139190.3\12_07_2...
# 32   G:\My Drive\2P_Data\TwoTower\4139190.3\14_07_2...
# 33   G:\My Drive\2P_Data\TwoTower\4139190.3\14_07_2...
# 34   G:\My Drive\2P_Data\TwoTower\4139190.3\14_07_2...
# 35   G:\My Drive\2P_Data\TwoTower\4139190.3\14_07_2...
# 238  G:\My Drive\2P_Data\TwoTower\4139190.3\14_07_2...
# 239  G:\My Drive\2P_Data\TwoTower\4139190.3\14_07_2...
# 241  G:\My Drive\2P_Data\TwoTower\4139190.3\14_07_2...
# 243  G:\My Drive\2P_Data\TwoTower\4139190.3\14_07_2...
# 50   G:\My Drive\2P_Data\TwoTower\4139190.3\16_07_2...
# 297  G:\My Drive\2P_Data\TwoTower\4139190.3\16_07_2...
# 397  G:\My Drive\2P_Data\TwoTower\4139190.3\18_07_2...
# 419  G:\My Drive\2P_Data\TwoTower\4139190.3\20_07_2...
# 427  G:\My Drive\2P_Data\TwoTower\4139190.3\22_07_2...
# 413  G:\My Drive\2P_Data\TwoTower\4139202.2\20_07_2...
# 414  G:\My Drive\2P_Data\TwoTower\4139202.2\20_07_2...
# 423  G:\My Drive\2P_Data\TwoTower\4139202.2\22_07_2...

# %%
for mouse in ca1mice+dgmice:
    print(mouse)
    # no timeeout 
    df_noTO = df[df['Track']=='TwoTower_noTimeout']
    df_noTO = df_noTO[df_noTO['MouseName'].str.match(mouse)]
    df_noTO
    # concatenate all files
    data_noTOs = behavior_dataframe([df_noTO['data file'].iloc[i] for i in range(df_noTO.shape[0])],scanmats=[df_noTO['scanmat'].iloc[i] for i in range(df_noTO.shape[0])],concat=False)

    
    # correct for frame times
    for data_noTO in data_noTOs:
        trial_mat, bin_edges, bin_centers = make_pos_bin_trial_matrices(data_noTO[['speed','morph','lick rate','reward','lick']]._values,
                                                          data_noTO['pos']._values,
                                                          data_noTO['tstart']._values,
                                                          data_noTO['teleport']._values,bin_size=5)

        #trial_mat[np.isnan(trial_mat)]=0
        morph_vec,count = sp.stats.mode(trial_mat[:,:,1],axis=1,nan_policy='omit')
        morph_vec = np.squeeze(morph_vec)

         # speed vs position
        speed_dict = trial_type_dict(trial_mat[:,:,0],morph_vec)

        f,ax = plot_speed(bin_centers,speed_dict,morph_vec)
        f.suptitle(mouse)

        # plot licking behavior 
        lick_dict = trial_type_dict(trial_mat[:,:,4],morph_vec)
        lick_mat = np.squeeze(trial_mat[:,:,2])
        lick_mat_norm = lick_dict['all']/np.amax(lick_dict['all'])
        lick_norm_dict = trial_type_dict(lick_mat_norm,morph_vec)
        fig,axes = lick_plot(lick_dict,bin_edges,smooth=False,ratio=True)

    # timeout
    
    # speed vs position
    
    # plot licking behavior
# Out:
# 4139190.1
# G:\My Drive\2P_Data\TwoTower\4139190.1\15_06_2018\TwoTower_noTimeout\TwoTower_noTimeout_3_000.mat
# (15277, 15)
# ..\utilities.py:262: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   frame['ca inds'] = caInds
# C:\Users\mplitt\Anaconda3\lib\site-packages\pandas\core\frame.py:3035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# (15277,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\15_06_2018\TwoTower_noTimeout\TwoTower_noTimeout_1_000.mat
# (19753, 15)
# (19753,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\16_06_2018\TwoTower_noTimeout\TwoTower_noTimeout_2_000.mat
# (22493, 15)
# (22493,)
# C:\Users\mplitt\Anaconda3\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# ..\utilities.py:572: RuntimeWarning: invalid value encountered in true_divide
#   rzone_lick_ratio[m] = np.divide(zone0_lick_rate,zone0_lick_rate+zone1_lick_rate)
# 4139190.3
# G:\My Drive\2P_Data\TwoTower\4139190.3\15_06_2018\TwoTower_noTimeout\TwoTower_noTimeout_3_000.mat
# (15177, 15)
# (15177,)
# G:\My Drive\2P_Data\TwoTower\4139190.3\15_06_2018\TwoTower_noTimeout\TwoTower_noTimeout_1_000.mat
# (22706, 15)
# (22706,)
# G:\My Drive\2P_Data\TwoTower\4139190.3\17_06_2018\TwoTower_noTimeout\TwoTower_noTimeout_2_000.mat
# (34762, 15)
# (34762,)
# 4054011.1
# G:\My Drive\2P_Data\TwoTower\4054011.1\17_06_2018\TwoTower_noTimeout\TwoTower_noTimeout_2_000.mat
# (30879, 15)
# (30879,)
# 4139202.2
# G:\My Drive\2P_Data\TwoTower\4139202.2\20_07_2018\TwoTower_noTimeout\TwoTower_noTimeout_001_002.mat
# (22052, 15)
# (22052,)
# G:\My Drive\2P_Data\TwoTower\4139202.2\20_07_2018\TwoTower_noTimeout\TwoTower_noTimeout_002_004.mat
# (16385, 15)
# (16385,)
# G:\My Drive\2P_Data\TwoTower\4139202.2\22_07_2018\TwoTower_noTimeout\TwoTower_noTimeout_002_001.mat
# (25552, 15)
# (25552,)
# 4054010.4
# G:\My Drive\2P_Data\TwoTower\4054010.4\15_06_2018\TwoTower_noTimeout\TwoTower_noTimeout_2_000.mat
# (18201, 15)
# (18201,)
# C:\Users\mplitt\Anaconda3\lib\site-packages\matplotlib\pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# 4054010.5
# G:\My Drive\2P_Data\TwoTower\4054010.5\15_06_2018\TwoTower_noTimeout\TwoTower_noTimeout_1_000.mat
# (12228, 15)
# (12228,)

# %%
for mouse in ['4139190.1']: #ca1mice+dgmice:
    print(mouse)
    # no timeeout 
    df_TO = df[df['Track']=='TwoTower_Timeout']
    df_TO = df_TO[df_TO['MouseName'].str.match(mouse)]
    df_TO
    # concatenate all files
    data_TOs = behavior_dataframe([df_TO['data file'].iloc[i] for i in range(df_TO.shape[0])],scanmats=[df_TO['scanmat'].iloc[i] for i in range(df_TO.shape[0])],concat=False)

    
    # correct for frame times
    for i,data_TO in enumerate(data_TOs):
       # try:
        trial_mat, bin_edges, bin_centers = make_pos_bin_trial_matrices(data_TO[['speed','morph','lick rate','reward','lick']]._values,
                                                      data_TO['pos']._values,
                                                      data_TO['tstart']._values,
                                                      data_TO['teleport']._values,bin_size=5)
        #except:
            #print(np.where(data_TO['tstart']._values>0)[0],np.where(data_noTO))

       
        morph_vec,count = sp.stats.mode(trial_mat[:,:,1],axis=1,nan_policy='omit')
        morph_vec = np.squeeze(morph_vec)

         # speed vs position
        speed_dict = trial_type_dict(trial_mat[:,:,0],morph_vec)

        f,ax = plot_speed(bin_centers,speed_dict,morph_vec)
        f.suptitle("%s : %s : %s" % (mouse,df_TO['DateFolder'].iloc[i],df_TO['SessionNumber'].iloc[i]))
        

        # plot licking behavior 
        lick_dict = trial_type_dict(trial_mat[:,:,4],morph_vec)
        lick_mat = np.squeeze(trial_mat[:,:,2])
        lick_mat_norm = lick_dict['all']/np.amax(lick_dict['all'])
        lick_norm_dict = trial_type_dict(lick_mat_norm,morph_vec)
        fig,axes = lick_plot(lick_dict,bin_edges,smooth=False,ratio=False)
                   
                   
        trial_info = by_trial_info(data_TO)
        pcnt_mean = avg_by_morph(trial_info['morphs'],trial_info['pcnt'])
        f,ax = plt.subplots(figsize=[5,5])
       # morph_vals = np.arange(0,1.25,.25)
        ax.plot(np.sort(np.unique(morph_vec)),pcnt_mean,color='black')
        #ax.plot(morph_vals,pcnt_mean_post,color='red')
        ax.set_ylabel("P(licked at second tower)")
        ax.set_xlabel("morph")
        ax.set_ylim([0,1])
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        
        # zone speeds
        zone0_speed = avg_by_morph(trial_info['morphs'],trial_info['zone0_speed'])
        zone1_speed = avg_by_morph(trial_info['morphs'],trial_info['zone1_speed'])
        f,ax = plt.subplots(1,2,figsize=[10,5])
        morph_vals = np.arange(0,1.25,.25)
        ax[0].plot(morph_vals,zone0_speed,color='black')
        ax[0].scatter(trial_info_pre['morphs'],trial_info_pre['zone0_speed'],color='black',s=5)
        ax[0].set_ylabel("cm/s")
        ax[0].set_xlabel("morph")
        ax[0].set_title("zone 0 speed")
        ax[0].spines['top'].set_visible(False)
        ax[0].spines['right'].set_visible(False)


        ax[1].plot(morph_vals,zone1_speed_pre,color='black')
        ax[1].scatter(trial_info_pre['morphs'],trial_info_pre['zone1_speed'],color='black',s=5)
        ax[1].set_ylabel("cm/s")
        ax[1].set_xlabel("morph")
        ax[1].set_title("zone 1 speed")
        ax[1].spines['top'].set_visible(False)
        ax[1].spines['right'].set_visible(False)
# Out:
# 4139190.1
# G:\My Drive\2P_Data\TwoTower\4139190.1\16_06_2018\TwoTower_Timeout\TwoTower_Timeout_2_000.mat
# ..\utilities.py:262: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   frame['ca inds'] = caInds
# C:\Users\mplitt\Anaconda3\lib\site-packages\pandas\core\frame.py:3035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# (19264,) (19264,) 15.4609375 19264
# (19256, 15)
# (19256,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\19_06_2018\TwoTower_Timeout\TwoTower_Timeout_2_000.mat
# (25617,) (25617,) 15.4609375 25617
# (25601, 15)
# (25601,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\21_06_2018\TwoTower_Timeout\TwoTower_Timeout_3_000.mat
# (32405,) (32406,) 15.4609375 32405
# (32381, 15)
# (32381,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\21_06_2018\TwoTower_Timeout\TwoTower_Timeout_2_000.mat
# (8366,) (8366,) 15.4609375 8366
# (8355, 15)
# (8355,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\24_06_2018\TwoTower_Timeout\TwoTower_Timeout_2_000.mat
# (36959,) (36959,) 15.4609375 36959
# (36921, 15)
# (36921,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\25_06_2018\TwoTower_Timeout\TwoTower_Timeout_2_000.mat
# (37032,) (37032,) 15.4609375 37032
# (36999, 15)
# (36999,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\27_06_2018\TwoTower_Timeout\TwoTower_Timeout_2_000.mat
# (39234,) (39234,) 15.4609375 39234
# (39203, 15)
# (39203,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\28_06_2018\TwoTower_Timeout\TwoTower_Timeout_8_000.mat
# (8879,) (8879,) 15.4609375 8879
# (8868, 15)
# (8868,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\28_06_2018\TwoTower_Timeout\TwoTower_Timeout_2_000.mat
# (5575,) (5575,) 15.4609375 5575
# (5563, 15)
# (5563,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\28_06_2018\TwoTower_Timeout\TwoTower_Timeout_9_000.mat
# (7386,) (7386,) 15.4609375 7386
# (7375, 15)
# (7375,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\11_07_2018\TwoTower_Timeout\TwoTower_Timeout_017_023.mat
# (17825,) (17825,) 15.4609375 17825
# (17795, 15)
# (17795,)
# G:\My Drive\2P_Data\TwoTower\4139190.1\11_07_2018\TwoTower_Timeout\TwoTower_Timeout_017_023.mat
# (17825,) (17825,) 15.4609375 17825
# (17795, 15)
# (17795,)
# C:\Users\mplitt\Anaconda3\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# ..\utilities.py:459: RuntimeWarning: Mean of empty slice
#   zone1_speed[i] = np.nanmean(sub_frame.loc[zone1_mask,'speed'])
# ..\utilities.py:458: RuntimeWarning: Mean of empty slice
#   zone0_speed[i]=np.nanmean(sub_frame.loc[zone0_mask,'speed'])
# C:\Users\mplitt\Anaconda3\lib\site-packages\matplotlib\pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ..\utilities.py:604: RuntimeWarning: Mean of empty slice
#   tmp = ax[0].plot(x,np.nanmean(d[m],axis=0),color=plt.cm.cool(np.float(m)),zorder=1)
# ..\utilities.py:605: RuntimeWarning: Mean of empty slice
#   tmp = ax[1].plot(x,np.nanmean(d[m],axis=0),color=plt.cm.cool(np.float(m)))
# ..\utilities.py:558: RuntimeWarning: Mean of empty slice
#   meanlr_ax.plot(bin_edges[:-1],np.nanmean(d[m],axis=0),color=plt.cm.cool(np.float(m)))
