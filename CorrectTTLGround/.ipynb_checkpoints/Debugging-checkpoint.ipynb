# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from scipy.ndimage.filters import gaussian_filter1d
import sqlite3 as sql
import os
import pandas as pd
from datetime import datetime
from glob import glob
import PlaceCellAnalysis as pc

os.sys.path.append('../')
import utilities as u
import preprocessing as pp
import behavior as b
import BayesianDecoding as bd


# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
# load a session where a know there is the right number of TTLs
df = pp.load_session_db()
df = df[df['RewardCount']>30]
df = df[df['Imaging']==1]
df = df.sort_values(['MouseName','DateTime','SessionNumber'])
mouse = '4139219.2'

# for mouse in  ['4139219.2', '4139219.3', '4139224.2', '4139224.3', '4139224.5',
#      '4139251.1','4139251.2','4139260.1','4139260.2','4139261.2','4139266.3','4139265.4']:

# %%
for mouse in ['4139219.2', '4139219.3', '4139224.2', '4139224.3', '4139224.5',
      '4139251.1','4139251.2','4139260.1','4139260.2','4139261.2','4139266.3','4139265.4','4139265.3','4139265.5']:
    f,ax = plt.subplots()
    df_mouse = df[df['MouseName'].str.match(mouse)]
    df_mouse = df_mouse[df_mouse['Track'].str.match('TwoTower_noTimeout') | df_mouse['Track'].str.match('TwoTower_Timeout')|
                       df_mouse['Track'].str.match('Reversal_noTimeout') | df_mouse['Track'].str.match('Reversal') |
                       df_mouse['Track'].str.match('TwoTower_foraging') ]
    print(mouse)
    # take first file
    for i in range(df_mouse.shape[0]):
        sess = df_mouse.iloc[i]
        print(sess)
    # load info file

        info = pp.loadmat_sbx(sess['scanmat'])['info']
        fr = info['resfreq']/info['recordsPerBuffer']
        lr = fr*512.
        info['max_idx'] = int(os.path.getsize(sess['scanmat'][:-3]+'sbx')/info['recordsPerBuffer']/info['sz'][1]*2/4-1)
        print('last indices',info['max_idx'],info['frame'][-1])
        print('first frames', info['frame'][0]/fr + info['line'][0]/lr)
        
        st = info['frame']/fr + info['line']/lr  
        dt_st = np.diff(st)
        
        vr = pp._get_frame(sess['data file'])
        if 'sanning' in vr.columns:
            key = 'sanning'
        elif 'scanning' in vr.columns:
            key = 'scanning'
        else:
            raise Exception("no scanning column")
            
        vr = vr[vr[key]>0]
        vr.time -= vr.time._values[0]
        print(vr[vr.time>9.9].iloc[0:10])
        
        dt_vr = np.diff(vr['time']._values)
        np.amin(dt_vr)
        vrt_r = np.round((vr.time._values-vr['time']._values[-1])*fr)/fr
        
        dt_st = np.insert(dt_st,0,np.amin(dt_vr))
        tmp = np.zeros(dt_st.shape)
        tmp[dt_st<.005]=1
        mask = np.insert(np.diff(tmp),0,0)
        mask[mask<0]=0
        
        st_clean = info['frame']/fr
        st_clean = st_clean[mask==0]
        print(st_clean.shape,st.shape)

            
#         bof = info['frame'].shape[0]
#         ax.plot(vrt_r[-1:-bof:-1000]-st_r[-1:-bof:-1000])
#         ff,aax = plt.subplots()
#         aax.scatter(dt_st[-1:-bof:-100],dt_vr[-1:-bof:-100])
#         print('num frames', bof) 
         
        print('bof')
        bof = info['frame'].shape[0]
        print(vr.iloc[-bof:-bof+2])
        clean_bof = st_clean.shape[0]
        if bof!=clean_bof:
            print(vr.iloc[-clean_bof:-clean_bof+2])
#         
#         for j in range(30):
#             print(vrt_r[-bof+j],st_r[-bof+j])
            

        # find time of first pulse

        # find closest VR time (first scanning=1 frame is time 0)

        # take second to last scan frame

        # take second to last vr frame
             
            
            
       
    
# # calculate inter TTL interval on scanning computer
# scanTime = info['frame']/fr + info['line']/lr
# dt_scanTime = np.diff(scanTime)
# print(scanTime.shape)

# # calculate inter frame interval on VR computer
# vr = pp._get_frame(sess['data file'])
# dt_vr = np.diff(vr['time']._values)
# # look at last ttl to see what the dealio is
    
# calculate average time between VR clock time and
# Out:
# 4139219.2
# MouseName                                                4139219.2
# DateFolder                                              08_10_2018
# SessionNumber                                                    1
# Track                                           TwoTower_noTimeout
# RewardCount                                                     63
# Imaging                                                          1
# ImagingRegion                                                  CA1
# DateTime                                       2018-10-08 00:00:00
# data file        G:\My Drive\\VR_Data\TwoTower\4139219.2\08_10_...
# scanfile         G:\My Drive\2P_Data\TwoTower\4139219.2\08_10_2...
# scanmat          G:\My Drive\2P_Data\TwoTower\4139219.2\08_10_2...
# s2pfolder        G:\My Drive\2P_Data\TwoTower\4139219.2\08_10_2...
# Name: 616, dtype: object
# G:\My Drive\2P_Data\TwoTower\4139219.2\08_10_2018\TwoTower_noTimeout\TwoTower_noTimeout_001_008.mat
# last indices 23896 23896
# first frames 8.637443153107629
#           time  morph  trialnum  pos      dz  lick  reward  tstart  teleport  \
# 1007   9.90290    1.0         0 -5.0  0.4023     0       0     0.0       0.0
# 1008   9.92335    1.0         0 -5.0  0.3576     0       0     0.0       0.0
# 1009   9.94387    1.0         0 -5.0  0.4023     0       0     0.0       0.0
# 1010   9.97668    1.0         0 -5.0  0.7599     0       0     0.0       0.0
# 1011   9.99709    1.0         0 -5.0  0.4470     0       0     0.0       0.0
# 1012  10.01763    1.0         0 -5.0  0.4917     0       0     0.0       0.0
# 1013  10.03826    1.0         0 -5.0  0.4917     0       0     0.0       0.0
# 1014  10.07137    1.0         0 -5.0  0.6258     0       0     0.0       0.0
# 1015  10.09127    1.0         0 -5.0  0.4470     0       0     0.0       0.0
# 1016  10.11176    1.0         0 -5.0  0.4470     0       0     0.0       0.0
#
#       rzone  toutzone  clickOn  blockWalls  towerJitter  wallJitter  \
# 1007      0         0        1           0     0.088229    0.043186
# 1008      0         0        1           0     0.088229    0.043186
# 1009      0         0        1           0     0.088229    0.043186
# 1010      0         0        1           0     0.088229    0.043186
# 1011      0         0        1           0     0.088229    0.043186
# 1012      0         0        1           0     0.088229    0.043186
# 1013      0         0        1           0     0.088229    0.043186
# 1014      0         0        1           0     0.088229    0.043186
# 1015      0         0        1           0     0.088229    0.043186
# 1016      0         0        1           0     0.088229    0.043186
#
#       bckgndJitter  sanning  manrewards      speed  lick rate
# 1007     -0.083701        1           0  19.710926        0.0
# 1008     -0.083701        1           0  17.486553        0.0
# 1009     -0.083701        1           0  19.605263        0.0
# 1010     -0.083701        1           0  23.160622        0.0
# 1011     -0.083701        1           0  21.901029        0.0
# 1012     -0.083701        1           0  23.938656        0.0
# 1013     -0.083701        1           0  23.834222        0.0
# 1014     -0.083701        1           0  18.900634        0.0
# 1015     -0.083701        1           0  22.462312        0.0
# 1016     -0.083701        1           0  21.815520        0.0
# (75957,) (75957,)
# bof
#           time  morph  trialnum  pos      dz  lick  reward  tstart  teleport  \
# 1014  10.07137    1.0         0 -5.0  0.6258     0       0     0.0       0.0
# 1015  10.09127    1.0         0 -5.0  0.4470     0       0     0.0       0.0
#
#       rzone  toutzone  clickOn  blockWalls  towerJitter  wallJitter  \
# 1014      0         0        1           0     0.088229    0.043186
# 1015      0         0        1           0     0.088229    0.043186
#
#       bckgndJitter  sanning  manrewards      speed  lick rate
# 1014     -0.083701        1           0  18.900634        0.0
# 1015     -0.083701        1           0  22.462312        0.0
# MouseName                                                4139219.2
# DateFolder                                              10_10_2018
# SessionNumber                                                    2
# Track                                           TwoTower_noTimeout
# RewardCount                                                     86
# Imaging                                                          1
# ImagingRegion                                                  CA1
# DateTime                                       2018-10-10 00:00:00
# data file        G:\My Drive\\VR_Data\TwoTower\4139219.2\10_10_...
# scanfile         G:\My Drive\2P_Data\TwoTower\4139219.2\10_10_2...
# scanmat          G:\My Drive\2P_Data\TwoTower\4139219.2\10_10_2...
# s2pfolder        G:\My Drive\2P_Data\TwoTower\4139219.2\10_10_2...
# Name: 651, dtype: object
# G:\My Drive\2P_Data\TwoTower\4139219.2\10_10_2018\TwoTower_noTimeout\TwoTower_noTimeout_002_002.mat
# last indices 30960 30960
# first frames 8.575416877210712
#           time  morph  trialnum  pos      dz  lick  reward  tstart  teleport  \
# 
zone  toutzone  clickOn  blockWalls  towerJitter  wallJitter  \
# 911      0         0        1           0    -0.012712   -0.000251
# 912      0         0        1           0    -0.012712   -0.000251
# 913      0         0        1           0    -0.012712   -0.000251
# 914      0         0        1           0    -0.012712   -0.000251
# 915      0         0        1           0    -0.012712   -0.000251
# 916      0         0        1           0    -0.012712   -0.000251
# 917      0         0        1           0    -0.012712   -0.000251
# 918      0         0        1           0    -0.012712   -0.000251
# 919      0         0        1           0    -0.012712   -0.000251
# 920      0         0        1           0    -0.012712   -0.000251
#
#      bckgndJitter  sanning  manrewards      speed  lick rate
# 911      0.091563        1           0  50.471281        0.0
# 912      0.091563        1           0  45.947137        0.0
# 913      0.091563        1           0  49.883552        0.0
# 914      0.091563        1           0  45.745614        0.0
# 915      0.091563        1           0  45.947137        0.0
# 916      0.091563        1           0  40.396246        0.0
# 917      0.091563        1           0  35.889201        0.0
# 918      0.091563        1           0  51.073025        0.0
# 919      0.091563        1           0  39.441176        0.0
# 920      0.091563        1           0  45.656615        0.0
# (52237,) (52237,)
# bof
#          time  morph  trialnum  pos      dz  lick  reward  tstart  teleport  \
# 917  10.04720   0.75         0 -5.0  0.8940     0       0     0.0       0.0
# 918  10.06733   0.75         0 -5.0  1.0281     0       0     0.0       0.0
#
#      rzone  toutzone  clickOn  blockWalls  towerJitter  wallJitter  \
# 917      0         0        1           0    -0.012712   -0.000251
# 918      0         0        1           0    -0.012712   -0.000251
#
#      bckgndJitter  sanning  manrewards      speed  lick rate
# 917      0.091563        1           0  35.889201        0.0
# 918      0.091563        1           0  51.073025        0.0
# MouseName                                                4139219.2
# DateFolder                                              23_10_2018
# SessionNumber                                                    2
# Track                                             TwoTower_Timeout
# RewardCount                                                    101
# Imaging                                                          1
# ImagingRegion                                                  CA1
# DateTime                                       2018-10-23 00:00:00
# data file        G:\My Drive\\VR_Data\TwoTower\4139219.2\23_10_...
# scanfile         G:\My Drive\2P_Data\TwoTower\4139219.2\23_10_2...
# scanmat          G:\My Drive\2P_Data\TwoTower\4139219.2\23_10_2...
# s2pfolder        G:\My Drive\2P_Data\TwoTower\4139219.2\23_10_2...
# Name: 872, dtype: object
# G:\My Drive\2P_Data\TwoTower\4139219.2\23_10_2018\TwoTower_Timeout\TwoTower_Timeout_002_011.mat
# last indices 29258 29258
# first frames 8.608640727640221
#           time  morph  trialnum  pos      dz  lick  reward  tstart  teleport  \
# 1335   9.91179    1.0         0 -5.0  1.7880     0       0     0.0       0.0
# 1336   9.93231    1.0         0 -5.0  0.8493     0       0     0.0       0.0
# 1337   9.95281    1.0         0 -5.0  0.9834     0       0     0.0       0.0
# 1338   9.97312    1.0         0 -5.0  0.9387     0       0     0.0       0.0
# 1339   9.98952    1.0         0 -5.0  0.8493     0       0     0.0       0.0
# 1340  10.01020    1.0         0 -5.0  0.8493     0       0     0.0       0.0
# 1341  10.03094    1.0         0 -5.0  1.0281     0       0     0.0       0.0
# 1342  10.07198    1.0         0 -5.0  2.1009     0       0     0.0       0.0
# 1343  10.09197    1.0         0 -5.0  0.9834     0       0     0.0       0.0
# 1344  10.11256    1.0         0 -5.0  1.0281     0       0     0.0       0.0
#
#       rzone  toutzone  clickOn  blockWalls  towerJitter  wallJitter  \
# 1335      0         0        1           0    -0.040572    0.056116
# 1336      0         0        1           0    -0.040572    0.056116
# 1337      0         0        1           0    -0.040572    0.056116
# 1338      0         0        1           0    -0.040572    0.056116
# 1339      0         0        1           0    -0.040572    0.056116
# 1340      0         0        1           0    -0.040572    0.056116
# 1341      0         0        1           0    -0.040572    0.056116
# 1342      0         0        1           0    -0.040572    0.056116
# 1343      0         0        1           0    -0.040572    0.056116
# 1344      0         0        1           0    -0.040572    0.056116
#
#       bckgndJitter  sanning  manrewards      speed  lick rate
# 
#
#       bckgndJitter  scanning  manrewards  cmd      speed  lick rate
# 1035      0.018878         1           0    0  30.661440        0.0
# 1036      0.018878         1           0    0  37.086384        0.0
# 1037      0.018878         1           0    0  37.086384        0.0
# 1038      0.018878         1           0    0  49.839721        0.0
# 1039      0.018878         1           0    9  38.738565        0.0
# 1040      0.018878         1           0    9  50.545723        0.0
# 1041      0.018878         1           0    0  39.615953        0.0
# 1042      0.018878         1           0    0  51.881491        0.0
# 1043      0.018878         1           0    0  37.268269        0.0
# 1044      0.018878         1           0    0  45.391683        0.0
#
# [10 rows x 21 columns]
# (52596,) (52596,)
# bof
#           time  morph  trialnum  pos      dz  lick  reward  tstart  teleport  \
# 1040  10.02235    1.0         0 -5.0  1.0281     0       0     0.0       0.0
# 1041  10.04266    1.0         0 -5.0  0.8046     0       0     0.0       0.0
#
#       rzone    ...      clickOn  blockWalls  towerJitter  wallJitter  \
# 1040      0    ...            0           0    -0.083787    0.054068
# 1041      0    ...            0           0    -0.083787    0.054068
#
#       bckgndJitter  scanning  manrewards  cmd      speed  lick rate
# 1040      0.018878         1           0    9  50.545723        0.0
# 1041      0.018878         1           0    0  39.615953        0.0
#
# [2 rows x 21 columns]
# MouseName                                                4139265.4
# DateFolder                                              07_02_2019
# SessionNumber                                                    4
# Track                                            TwoTower_foraging
# RewardCount                                                     60
# Imaging                                                          1
# ImagingRegion                                                  CA1
# DateTime                                       2019-02-07 00:00:00
# data file        G:\My Drive\\VR_Data\TwoTower\4139265.4\07_02_...
# scanfile                                                      None
# scanmat          G:\My Drive\2P_Data\TwoTower\4139265.4\07_02_2...
# s2pfolder        G:\My Drive\2P_Data\TwoTower\4139265.4\07_02_2...
# Name: 1373, dtype: object
# G:\My Drive\2P_Data\TwoTower\4139265.4\07_02_2019\TwoTower_foraging\TwoTower_foraging_004_004.mat
# last indices 16060 16060
# first frames 8.589691763516926
#           time  morph  trialnum  pos      dz  lick  reward  tstart  teleport  \
# 1187   9.90349    0.0         0 -5.0  0.3129     0       0     0.0       0.0
# 1188   9.91987    0.0         0 -5.0  0.3129     0       0     0.0       0.0
# 1189   9.93640    0.0         0 -5.0  0.4470     0       0     0.0       0.0
# 1190   9.95277    0.0         0 -5.0  0.3576     0       0     0.0       0.0
# 1191   9.97325    0.0         0 -5.0  0.4917     0       0     0.0       0.0
# 1192   9.98974    0.0         0 -5.0  0.3129     0       0     0.0       0.0
# 1193  10.00598    0.0         0 -5.0  0.4023     0       0     0.0       0.0
# 1194  10.01816    0.0         0 -5.0  0.3129     0       0     0.0       0.0
# 1195  10.03469    0.0         0 -5.0  0.2682     0       0     0.0       0.0
# 1196  10.04685    0.0         0 -5.0  0.2682     0       0     0.0       0.0
#
#       rzone    ...      clickOn  blockWalls  towerJitter  wallJitter  \
# 1187      0    ...            0           0      0.08588    0.080701
# 1188      0    ...            0           0      0.08588    0.080701
# 1189      0    ...            0           0      0.08588    0.080701
# 1190      0    ...            0           0      0.08588    0.080701
# 1191      0    ...            0           0      0.08588    0.080701
# 1192      0    ...            0           0      0.08588    0.080701
# 1193      0    ...            0           0      0.08588    0.080701
# 1194      0    ...            0           0      0.08588    0.080701
# 1195      0    ...            0           0      0.08588    0.080701
# 1196      0    ...            0           0      0.08588    0.080701
#
#       bckgndJitter  scanning  manrewards  cmd      speed  lick rate
# 1187     -0.098462         1           0    0  25.480456        0.0
# 1188     -0.098462         1           0    0  19.102564        0.0
# 1189     -0.098462         1           0    0  27.041742        0.0
# 1190     -0.098462         1           0    0  21.844838        0.0
# 1191     -0.098462         1           0    0  24.008789        0.0
# 1192     -0.098462         1           0    0  18.975136        0.0
# 1193     -0.098462         1           0    9  24.772167        0.0
# 1194     -0.098462         1           0    9  25.689655        0.0
# 1195     -0.098462         1           0    0  16.225045        0.0
# 1196     -0.098462         1           0    0  22.055921        0.0
#
# [10 rows x 21 columns]
# (51653,) (51653,)
# bof
#           time  morph  trialnum  pos      dz  lick  reward  tstart  teleport  \
# 1194  10.01816    0.0         0 -5.0  0.3129     0       0     0.0       0.0
# 1195  10.03469    0.0         0 -5.0  0.2682     0       0     0.0       0.0
#
#       rzone    ...      clickOn  blockWalls  towerJitter  wallJitter  \
# 1194      0    ...            0           0      0.08588    0.080701
# 1195      0    ...            0           0      0.08588    0.080701
#
#       bckgndJitter  scanning  manrewards  cmd      speed  lick rate
# 1194     -0.098462         1           0    9  25.689655        0.0
# 1195     -0.098462         1           0    0  16.225045        0.0
#
# [2 rows x 21 columns]
# MouseName                                                4139265.4
# DateFolder                                              10_02_2019
# SessionNumber                                                    2
# Track                                            TwoTower_foraging
# RewardCount                                                     60
# Imaging                                                          1
# ImagingRegion                                                  CA1
# DateTime                                       2019-02-10 00:00:00
# data file        G:\My Drive\\VR_Data\TwoTower\4139265.4\10_02_...
# scanfile                                                      None
# scanmat          G:\My Drive\2P_Data\TwoTower\4139265.4\10_02_2...
# s2pfolder        G:\My Drive\2P_Data\TwoTower\4139265.4\10_02_2...
# Name: 1407, dtype: object
# G:\My Drive\2P_Data\TwoTower\4139265.4\10_02_2019\TwoTower_foraging\TwoTower_foraging_002_002.mat
# last indices 13506 13506
# first frames 8.576048509348155
#           time  morph  trialnum  pos      dz  lick  reward  tstart  teleport  \
# 1207   9.90757    1.0         0 -5.0  1.2069     0       0     0.0       0.0
# 1208   9.92386    1.0         0 -5.0  1.2516     0       0     0.0       0.0
# 1209   9.94441    1.0         0 -5.0  1.3410     0       0     0.0       0.0
# 1210   9.96889    1.0         0 -5.0  1.7880     0       0     0.0       0.0
# 1211   9.98543    1.0         0 -5.0  0.9834     0       0     0.0       0.0
# 1212  10.00985    1.0         0 -5.0  1.6986     0       0     0.0       0.0
# 1213  10.03035    1.0         0 -5.0  1.1175     0       0     0.0       0.0
# 1214  10.04672    1.0         0 -5.0  1.2963     0       0     0.0       0.0
# 1215  10.06305    1.0         0 -5.0  0.9834     0       0     0.0       0.0
# 1216  10.07945    1.0         0 -5.0  1.2069     0       0     0.0       0.0
#
#       rzone    ...      clickOn  blockWalls  towerJitter  wallJitter  \
# 1207      0    ...            0           0     0.002408   -0.093669
# 1208      0    ...            0           0     0.002408   -0.093669
# 1209      0    ...            0           0     0.002408   -0.093669
# 1210      0    ...            0           0     0.002408   -0.093669
# 1211      0    ...            0           0     0.002408   -0.093669
# 1212      0    ...            0           0     0.002408   -0.093669
# 1213      0    ...            0           0     0.002408   -0.093669
# 1214      0    ...            0           0     0.002408   -0.093669
# 1215      0    ...            0           0     0.002408   -0.093669
# 1216      0    ...            0           0     0.002408   -0.093669
#
#       bckgndJitter  scanning  manrewards  cmd      speed  lick rate
# 1207      -0.03119         1           0    0  58.959453        0.0
# 1208      -0.03119         1           0    0  76.832413        0.0
# 1209      -0.03119         1           0    0  65.255474        0.0
# 1210      -0.03119         1           0    0  73.039216        0.0
# 1211      -0.03119         1           0    0  59.455865        0.0
# 1212      -0.03119         1           0    9  69.557740        0.0
# 1213      -0.03119         1           0    9  54.512195        0.0
# 1214      -0.03119         1           0    0  79.187538        0.0
# 1215      -0.03119         1           0    0  60.220453        0.0
# 1216      -0.03119         1           0    0  73.591463        0.0
#
# [10 rows x 21 columns]
# (45655,) (45655,)
# bof
#           time  morph  trialnum  pos      dz  lick  reward  tstart  teleport  \
# 1213  10.03035    1.0         0 -5.0  1.1175     0       0     0.0       0.0
# 1214  10.04672    1.0         0 -5.0  1.2963     0       0     0.0       0.0
#
#       rzone    ...      clickOn  blockWalls  towerJitter  wallJitter  \
# 1213      0    ...            0           0     0.002408   -0.093669
# 1214      0    ...            0           0     0.002408   -0.093669
#
#       bckgndJitter  scanning  manrewards  cmd      speed  lick rate
# 1213      -0.03119         1           0    9  54.512195        0.0
# 1214      -0.03119         1           0    0  79.187538        0.0
#
# [2 rows x 21 columns]

# %%
print(df_mouse.columns)
# Out:
# Index(['MouseName', 'DateFolder', 'SessionNumber', 'Track', 'RewardCount',
#        'Imaging', 'ImagingRegion', 'DateTime', 'data file', 'scanfile',
#        'scanmat', 's2pfolder'],
#       dtype='object')

# %%
for i in range(1,10,1):
    print(dt_vr[-i],dt_scanTime[-i])
# Out:
# 0.09000000000014552 0.1543708943911497
# 0.01999999999998181 0.020717534107916435
# 0.01700000000005275 0.020591207680581647
# 0.01999999999998181 0.016296109146196613
# 0.020999999999958163 0.020464881253019485
# 0.01999999999998181 0.02033855482591207
# 0.01700000000005275 0.02071753410814381
# 0.03199999999992542 0.016422435573531402
# 0.020999999999958163 0.03259221829193848

# %%
info['frame'][-1]/fr
# Out:
# 1060.9964628600303

# %%
f,ax = plt.subplots()
ax.plot(info['line'])

# %%
vr.columns
# Out:
# Index(['time', 'morph', 'trialnum', 'pos', 'dz', 'lick', 'reward', 'tstart',
#        'teleport', 'rzone', 'toutzone', 'clickOn', 'blockWalls', 'towerJitter',
#        'wallJitter', 'bckgndJitter', 'sanning', 'manrewards', 'speed',
#        'lick rate'],
#       dtype='object')

# %%
vr_t = vr['time']._values[-info['frame'].shape[0]:]

# %%
print(vr_t.shape,info['frame'].shape)
# Out:
# (48743,) (48743,)

# %%
vr_t-=vr_t[0]
scanTime-=scanTime[0]

# %%
f,ax = plt.subplots()
ax.plot(scanTime,vr_t)
ax.plot(scanTime,scanTime)
#ax.set_xlim([0,1])
#ax.set_ylim([0,1])

# %%
h,edges = np.histogram(scanTime-vr_t)

# %%
print(h,edges)
# Out:
# [    1     0     0     0     0     0     0     0     0 48742] [-32.21799652 -28.95826481 -25.6985331  -22.43880139 -19.17906967
#  -15.91933796 -12.65960625  -9.39987454  -6.14014282  -2.88041111
#    0.3793206 ]

# %%
print(vr_t[-1],scanTime[-1])
print(fr)
# Out:
# 1084.70928 1052.4912834765032
# 15.4609375

# %%
for i in range(1,scanTime.shape[0],1):
    #print(vr_t[-i],scanTime[-i])
    if i%1000==1:
        print(i)
        print(vr_t[i],scanTime[i],np.floor(vr_t[i]*fr),np.floor(vr_t[i]*fr))
# Out:
# 1
# 0.020080000000000098 0.01642243557352252 0.0 0.0
# 1001
# 19.20456 19.2122283981809 296.0 296.0
# 2001
# 38.282450000000004 38.30381505811016 591.0 591.0
# 3001
# 57.50376000000001 57.52968671045983 889.0 889.0
# 4001
# 76.90117000000001 76.94340576048509 1188.0 1188.0
# 5001
# 96.02826999999999 96.06998484082871 1484.0 1484.0
# 6001
# 114.97926999999999 115.027918140475 1777.0 1777.0
# 7001
# 134.06127 134.11710459828194 2072.0 2072.0
# 8001
# 153.23767 153.30027791814047 2369.0 2369.0
# 9001
# 172.79877000000002 172.87241030823648 2671.0 2671.0
# 10001
# 192.97847 193.05482566953006 2983.0 2983.0
# 11001
# 213.27697000000003 213.36015664477006 3297.0 3297.0
# 12001
# 234.66497 234.75543203638202 3628.0 3628.0
# 13001
# 257.04407 257.15411824153614 3974.0 3974.0
# 14001
# 279.98026999999996 280.0856493178373 4328.0 4328.0
# 15001
# 303.37906999999996 303.4922940879232 4690.0 4690.0
# 16001
# 326.79447 326.91965639211725 5052.0 5052.0
# 17001
# 349.95586999999995 350.0842597271349 5410.0 5410.0
# 18001
# 372.72416999999996 372.85990399191513 5762.0 5762.0
# 19001
# 395.72587 395.8688731682668 6118.0 6118.0
# 20001
# 418.84606999999994 419.005179383527 6475.0 6475.0
# 21001
# 441.74546999999995 441.90336028297116 6829.0 6829.0
# 22001
# 464.44397 464.60939868620517 7180.0 7180.0
# 23001
# 487.0318699999999 487.20464881253156 7529.0 7529.0
# 24001
# 509.6364699999999 509.82036382011125 7879.0 7879.0
# 25001
# 532.40857 532.5918393127843 8231.0 8231.0
# 26001
# 555.0170700000001 555.2200606366852 8581.0 8581.0
# 27001
# 577.7852700000001 577.9874936836786 8933.0 8933.0
# 28001
# 600.5492700000001 600.7588428499242 9285.0 9285.0
# 29001
# 623.06757 623.284360788277 9633.0 9633.0
# 30001
# 645.4428700000001 645.6668772107125 9979.0 9979.0
# 31001
# 667.77277 668.0039161192522 10324.0 10324.0
# 32001
# 690.2130700000001 690.4514906518444 10671.0 10671.0
# 33001
# 712.7028700000001 712.956796361799 11019.0 11019.0
# 34001
# 735.10657 735.3595250126327 11365.0 11365.0
# 35001
# 756.9613700000001 757.2215765538151 11703.0 11703.0
# 36001
# 779.1643700000001 779.4316574027287 12046.0 12046.0
# 37001
# 801.1994700000001 801.4737241030824 12387.0 12387.0
# 38001
# 823.09517 823.3807478524508 12725.0 12725.0
# 39001
# 844.7083700000001 844.9926730672057 13059.0 13059.0
# 40001
# 866.22747 866.522738756948 13392.0 13392.0
# 41001
# 887.59887 887.9012127337039 13723.0 13723.0
# 42001
# 909.0196700000001 909.3289540171804 14054.0 14054.0
# 43001
# 930.36657 930.6787518948964 14384.0 14384.0
# 44001
# 951.7258700000001 952.0611419909045 14714.0 14714.0
# 45001
# 973.0320700000001 973.3739262253664 15043.0 15043.0
# 46001
# 994.5060700000001 994.8425972713492 15375.0 15375.0
# 47001
# 1015.6150700000001 1015.9711975745327 15702.0 15702.0
# 48001
# 1036.5850699999999 1036.9356998484084 16026.0 16026.0

# %%
print(info['channels'],sess.scanmat)
info['max_idx'] = int(os.path.getsize(sess['scanmat'][:-3]+'sbx')/info['recordsPerBuffer']/info['sz'][1]*2/4-1)
# Out:
# 2 G:\My Drive\2P_Data\TwoTower\4139224.5\18_10_2018\TwoTower_noTimeout\TwoTower_noTimeout_001_008.mat

# %%
print(info['max_idx'],info['frame'][-1])
# Out:
# 16404 16404

# %%
h,edges = np.histogram(np.diff(vr_t))

# %%
print(h,edges)
# Out:
# [38389  5873  4208   199    14     0     2    40    13     4] [0.0121  0.02206 0.03202 0.04198 0.05194 0.0619  0.07186 0.08182 0.09178
#  0.10174 0.1117 ]

# %%
print(info['frame'][0]/fr + info['line'][0]/lr)
# Out:
# 8.557731177362303

# %%
print(vr['time']._values[-1],
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('time', -1)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-5aa398ef8236> in <module>()
# ----> 1 vr['time',-1]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('time', -1)
