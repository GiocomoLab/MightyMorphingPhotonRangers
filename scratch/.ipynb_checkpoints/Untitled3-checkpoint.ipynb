# %%
import numpy as np
from SplineEncodingModel import LinearRegressionSpline as lrsp
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
f,ax = plt.subplots(figsize= [15,5])
y = np.linspace(0.1,100)
for lam in np.arange(0.1,50,5).tolist():
    ax.plot(y,lrsp._gamma_pdf(y,lam))
    print(lrsp._gamma_pdf(y,lam).sum())
# Out:
# 0.7583748157409947
# 0.4905274048839489
# 0.4904905192576973
# 0.4904904905762605
# 0.49049049049082116
# 0.4904904904904919
# 0.4904904904904903
# 0.49049049049049026
# 0.4904904904904902
# 0.4904904904903206
