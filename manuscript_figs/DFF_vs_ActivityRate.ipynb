# %%
import os
os.sys.path.append("C:\\Users\mplitt\MightyMorphingPhotonRangers")
import utilities as u
import preprocessing as pp
import single_session_plots as ssp
import numpy as np
import SimilarityMatrixAnalysis as sm
import PlaceCellAnalysis as pc
import scipy as sp
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pp.load_session_db()
df = df[df['RewardCount']>20]
df = df[df['Imaging']==1]
df = df.sort_values(['MouseName','DateTime','SessionNumber'])
# Out:
# G:\My Drive\VR_Data\TwoTower\behavior.sqlite
# G:\My Drive\VR_Data\TwoTower\4222174.0\30_05_2019\RuningTraining_1.sqlite
# file doesn't exist, errors to come!!!

# %%
mouse = '4139265.5'
df_mouse = df[df['MouseName'].str.match(mouse)]
df_mouse
# Out:
#       MouseName  DateFolder  SessionNumber              Track  RewardCount  \
# 1410  4139265.5  10_02_2019              1  TwoTower_foraging           60
# 1412  4139265.5  10_02_2019              3  TwoTower_foraging           60
# 1439  4139265.5  12_02_2019              2  TwoTower_foraging           90
# 1462  4139265.5  15_02_2019              2  TwoTower_foraging           86
# 1481  4139265.5  17_02_2019              2  TwoTower_foraging           80
# 1501  4139265.5  19_02_2019              2  TwoTower_foraging           97
# 1519  4139265.5  21_02_2019              2  TwoTower_foraging          105
# 1528  4139265.5  22_02_2019              2  TwoTower_foraging           98
# 1534  4139265.5  23_02_2019              2  TwoTower_foraging           96
# 1539  4139265.5  24_02_2019              2  TwoTower_foraging           90
#
#       Imaging ImagingRegion   DateTime  \
# 1410        1           CA1 2019-02-10
# 1412        1           CA1 2019-02-10
# ...

# %%
sess = df_mouse.iloc[-1]
VRDat,C, S, F = pp.load_scan_sess(sess)
# Out:
# num aberrant ttls 0.0
# 36583 (36583,) (36583, 21) 124384
# C:\Users\mplitt\Anaconda3\lib\site-packages\pandas\core\frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# frame diff 0

# %%
C = u.df(F,ops={'sig_baseline':10,'win_baseline':300,'sig_output':2,'method':'maximin'})

# %%
maxT = C.shape[0]/15.46
t = np.linspace(0,maxT,num=C.shape[0])
cells = np.random.permutation(C.shape[1])
Cn=C/15.46/400 #np.amax(C,axis=0)[np.newaxis,:]*.9
Sn = S/15.46/400 #np.amax(S,axis=0)[np.newaxis,:]*.9
f,ax = plt.subplots(figsize=[10,10])
for i,cell in enumerate(cells[50:60]): #range(1,C.shape[1],10):
    
    n = 5000
    ax.plot(t[:n],Cn[:n,cell]+i,color='red',alpha=.4)
    ax.plot(t[:n],Sn[:n,cell]+i,color='black',alpha=1)
#     ax.set_title('cell %i' % cell)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.legend(('df/F','deconv. activity rate'))
    #ax.plot(t[-5000:],A[-5000:,cell]/15.46)

# %%
f.savefig('G:\\My Drive\\manuscripts\\MightyMorphinPhotonRangers\\Figures\\randomcells_4139265.3_24_02_2019.svg',format='svg')
